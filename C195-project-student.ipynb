# %%
print("Name:")
print("We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level")
print("We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it")
# Out:
# Name:
# We will be cleaning heart disease data, and conclude which age group has high risk of heart stroke as per diabetes and hight blood pressure level
# We will also find which gender has the most not normal platelets count in blood, and plot a pie chart around it

# %% [markdown]
# # Task 1 - Find the diabetic and hight blood pressure patients across all age groups, and conclude the risk heart stroke is higher in which age group

# %%
#Import libraries
import pandas as pd
import matplotlib.pyplot as plt 

#read the csv
df = pd.read_csv('heart_disease.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 0                      1  265000.00               1.9           130       1
# 1                      0  263358.03               1.1           136       1
# 2                      0  162000.00               1.3           129       1
# 3                      0  210000.00               1.9           137       1
# 4                      0  327000.00               2.7           116       0
# ..                   ...        ...               ...           ...     ...
# 294                    1  155000.00               1.1           143       1
# 295                    0  270000.00               1.2           139       0
# 296                    0  742000.00               0.8           138       0
# 297                    0  140000.00               1.4           140       1
# 298                    0  395000.00               1.6           136       1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 1          0     6            1
# 2          1     7            1
# 3          0     7            1
# 4          0     8            1
# ..       ...   ...          ...
# 294        1   270            0
# 295        0   271            0
# 296        0   278            0
# 297        1   280            0
# 298        1   285            0
#
# [299 rows x 13 columns]

# %%
#Filter by diabetes(condition will be who has diabetes) and create new dataframe

diabetes = df.loc[df["diabetes"] == 1]
diabetes
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4    65.0        1                       160         1                 20
# 7    60.0        1                       315         1                 60
# 19   48.0        1                       582         1                 55
# 21   65.0        1                       128         1                 30
# 23   53.0        0                        63         1                 60
# ..    ...      ...                       ...       ...                ...
# 290  45.0        0                       615         1                 55
# 292  52.0        0                       190         1                 38
# 293  63.0        1                       103         1                 35
# 294  62.0        0                        61         1                 38
# 296  45.0        0                      2060         1                 60
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 4                      0   327000.0               2.7           116       0
# 7                      0   454000.0               1.1           131       1
# 19                     0    87000.0               1.9           121       0
# 21                     1   297000.0               1.6           136       0
# 23                     0   368000.0               0.8           135       1
# ..                   ...        ...               ...           ...     ...
# 290                    0   222000.0               0.8           141       0
# 292                    0   382000.0               1.0           140       1
# 293                    0   179000.0               0.9           136       1
# 294                    1   155000.0               1.1           143       1
# 296                    0   742000.0               0.8           138       0
#
#      smoking  time  DEATH_EVENT
# 4          0     8            1
# 7          1    10            1
# 19         0    15            1
# 21         0    20            1
# 23         0    22            0
# ..       ...   ...          ...
# 290        0   257            0
# 292        1   258            0
# 293        1   270            0
# 294        1   270            0
# 296        0   278            0
#
# [125 rows x 13 columns]

# %%
#On this new data frame perform group operation as per age and create new dataframe 

group = diabetes.groupby("age")["diabetes"].count().reset_index()
group
# Out:
#        age  diabetes
# 0   40.000         2
# 1   42.000         2
# 2   44.000         2
# 3   45.000        11
# 4   46.000         1
# 5   48.000         2
# 6   49.000         1
# 7   50.000        12
# 8   51.000         2
# 9   52.000         2
# 10  53.000         3
# 11  54.000         1
# 12  55.000         4
# 13  56.000         1
# 14  58.000         5
# 15  59.000         3
# 16  60.000        19
# 17  60.667         2
# 18  61.000         2
# 19  62.000         3
# 20  63.000         4
# 21  65.000        15
# 22  66.000         1
# 23  68.000         2
# 24  69.000         1
# 25  70.000         9
# 26  72.000         2
# 27  73.000         1
# 28  75.000         3
# 29  80.000         3
# 30  82.000         2
# 31  90.000         1
# 32  94.000         1

# %%
#Filter by high_blood_pressure(condition will be who has high_blood_pressure) and create new dataframe

high_blood_pressure = df.loc[df["high_blood_pressure"] == 1]
high_blood_pressure
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 5    90.0        1                        47         0                 40
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# 11   62.0        0                       231         0                 25
# ..    ...      ...                       ...       ...                ...
# 255  52.0        1                       191         1                 30
# 257  58.0        0                       132         1                 38
# 270  44.0        0                       582         1                 30
# 275  45.0        0                       582         0                 38
# 294  62.0        0                        61         1                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 0                      1  265000.00               1.9           130       1
# 5                      1  204000.00               2.1           132       1
# 9                      1  388000.00               9.4           133       1
# 10                     1  368000.00               4.0           131       1
# 11                     1  253000.00               0.9           140       1
# ..                   ...        ...               ...           ...     ...
# 255                    1  334000.00               1.0           142       1
# 257                    1  253000.00               1.0           139       1
# 270                    1  263358.03               1.6           130       1
# 275                    1  422000.00               0.8           137       0
# 294                    1  155000.00               1.1           143       1
#
#      smoking  time  DEATH_EVENT
# 0          0     4            1
# 5          1     8            1
# 9          1    10            1
# 10         1    10            1
# 11         1    10            1
# ..       ...   ...          ...
# 255        1   216            0
# 257        0   230            0
# 270        1   244            0
# 275        0   245            0
# 294        1   270            0
#
# [105 rows x 13 columns]

# %%
#On this new data frame perform group operation as per age and create new dataframe 

group1 = high_blood_pressure.groupby("age")["high_blood_pressure"].count().reset_index()
group1
# Out:
#        age  high_blood_pressure
# 0   40.000                    1
# 1   44.000                    2
# 2   45.000                    5
# 3   46.000                    2
# 4   48.000                    1
# 5   49.000                    3
# 6   50.000                   10
# 7   51.000                    1
# 8   52.000                    1
# 9   53.000                    3
# 10  54.000                    1
# 11  55.000                    4
# 12  57.000                    1
# 13  58.000                    3
# 14  59.000                    2
# 15  60.000                    9
# 16  60.667                    1
# 17  61.000                    2
# 18  62.000                    3
# 19  63.000                    2
# 20  65.000                    8
# 21  66.000                    2
# 22  68.000                    2
# 23  70.000                   13
# 24  72.000                    5
# 25  73.000                    2
# 26  75.000                    7
# 27  77.000                    1
# 28  79.000                    1
# 29  80.000                    3
# 30  82.000                    1
# 31  90.000                    1
# 32  94.000                    1
# 33  95.000                    1

# %%
#plot the scatter graph to show which age group is more prone to diabetes

age = group["age"]
age1 = group1["age"]

plt.scatter(age, age1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 6
#       3 age = group["age"]
#       4 age1 = group1["age"]
# ----> 6 plt.scatter(age, age1)
#       7 plt.show()
#
# File ~/Downloads/anaconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
#    2836         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2837         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2838         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2839         **({"data": data} if data is not None else {}), **kwargs)
#    2840     sci(__ret)
#    2841     return __ret
#
# File ~/Downloads/anaconda3/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/Downloads/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4584, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4582 y = np.ma.ravel(y)
#    4583 if x.size != y.size:
# -> 4584     raise ValueError("x and y must be the same size")
#    4586 if s is None:
#    4587     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4588          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %% [markdown]
# Conclusion -

# %% [markdown]
# # Task 2 - Find as per gender who has not normal platelets level in blood

# %%
#Filter by platelets(condition lesser then 150000 OR greater then 450000) and create new dataframe

df

platelets = df.loc[df["platelets"] > 450000]
platelets
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 7    60.0        1                       315         1                 60
# 47   60.0        0                       582         1                 38
# 55   95.0        1                       371         0                 30
# 69   65.0        0                       113         1                 25
# 105  72.0        1                       328         0                 30
# 109  45.0        0                       292         1                 35
# 117  85.0        1                       102         0                 60
# 212  78.0        0                       224         0                 50
# 224  58.0        0                       582         1                 25
# 240  70.0        0                        81         1                 35
# 279  55.0        0                        84         1                 38
# 287  45.0        0                       582         1                 55
# 296  45.0        0                      2060         1                 60
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  gender  \
# 7                      0   454000.0              1.10           131       1
# 47                     1   451000.0              0.60           138       1
# 55                     0   461000.0              2.00           132       1
# 69                     0   497000.0              1.83           135       1
# 105                    1   621000.0              1.70           138       0
# 109                    0   850000.0              1.30           142       1
# 117                    0   507000.0              3.20           138       0
# 212                    0   481000.0              1.40           138       1
# 224                    0   504000.0              1.00           138       1
# 240                    1   533000.0              1.30           139       0
# 279                    0   451000.0              1.30           136       0
# 287                    0   543000.0              1.00           132       0
# 296                    0   742000.0              0.80           138       0
#
#      smoking  time  DEATH_EVENT
# 7          1    10            1
# 47         1    40            1
# 55         0    50            1
# 69         0    67            1
# 105        1    88            1
# 109        1    88            0
# 117        0    94            0
# 212        1   192            0
# 224        0   205            0
# 240        0   212            0
# 279        0   246            0
# 287        0   250            0
# 296        0   278            0

# %%
#On this new dataframe perform group operation as per gender and create new dataframe 

g = platelets.groupby("gender")["platelets"].count().reset_index()
g
# Out:
#    gender  platelets
# 0       0          6
# 1       1          7

# %%
#Plot a pie chart as per the gender to show the percentage of male and female who has not normal platelets

f = g["gender"]

label = f
value = g["platelets"]

plt.pie(label, value, autopct = "%0.2f%%", radius = 4)
plt.show()

# %% [markdown]
# Conclusion -
